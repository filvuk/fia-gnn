# %%
import os
import pandas as pd

# %%
os.path.join((os.path.split(os.getcwd())[0]), "data")
# Out:
# ['readme.txt']

# %%
os.path.join((os.path.split(os.getcwd())[0]), "data", "FIA49k.csv.gz")
# Out:
# 'F:\\FIA_GENERATION\\for_publication\\fia-gnn-dev\\data\\FIA49k.csv.gz'

# %%
x = pd.read_csv(os.path.join((os.path.split(os.getcwd())[0]), "data", "FIA49k.csv.gz"))

# %%
x
# Out:
#             Compound atoms_binding_to_central_atom_info  ca ca_class  \
# 0       Al_3_B000108         C(SP2)-1_N(SP3)-1_S(SP3)-1  Al  Al(III)
# 1       Al_3_B000109                  C(SP2)-2_N(SP3)-1  Al  Al(III)
# 2       Al_3_B000111         N(SP2)-1_O(SP3)-1_S(SP3)-1  Al  Al(III)
# 3       Al_3_B000112                  C(SP2)-1_S(SP3)-2  Al  Al(III)
# 4       Al_3_B000113         N(SP2)-1_S(SP2)-1_S(SP3)-1  Al  Al(III)
# ...              ...                                ...  ..      ...
# 48981  Te_4_ZT029149                  C(SP2)-1_N(SP2)-3  Te   Te(IV)
# 48982  Te_4_ZT029151                  C(SP2)-2_N(SP3)-2  Te   Te(IV)
# 48983  Te_4_ZT029152                  N(SP2)-2_N(SP3)-2  Te   Te(IV)
# 48984  Te_4_ZT029154                  N(SP2)-3_O(SP3)-1  Te   Te(IV)
# 48985  Te_4_ZT029157                  C(SP2)-1_N(SP3)-3  Te   Te(IV)
#
#        ca_group  ca_ox_number  ca_period denticity_class  \
# 0            13             3          3              bi
# ...
